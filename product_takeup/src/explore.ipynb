# %%
import seaborn as sns
import feather
sns.set()

# %%
data = feather.read_dataframe('../data/train_data')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 21 columns):
# LoanClient                140000 non-null int32
# Inflows_Total             118758 non-null float64
# Outflows_Total_L3M        118675 non-null float64
# Inflows_Above_1k          118758 non-null float64
# Max_Dep_Bal_L3M           134756 non-null float64
# InactiveLoanClient        140000 non-null int32
# Other_Perc_L3M            121116 non-null float64
# Outflow_Max_L3M           118675 non-null float64
# Inflows_Max_AVG_Day       118758 non-null float64
# DormantLoanClient         140000 non-null int32
# Ave_Days_Above_100_L3M    134756 non-null float64
# CW_Perc_L3M               121116 non-null float64
# DO_Perc_L3M               121116 non-null float64
# DODispute_L3M             121116 non-null float64
# Val_POS_L3M               121116 non-null float64
# Val_DO_L3M                121116 non-null float64
# Avg_Dep_Bal_L3M           134756 non-null float64
# ...

# %% [markdown]
# ### Check the number of missing values per observation for numerical variables. We might have to drop rows with too many missing values.

# %%
data.select_dtypes(include='float64').isnull().sum(axis=1).plot(kind='hist')

# %% [markdown]
# ### Check the number of missing values per observation for categorical variables.

# %%
data.select_dtypes(include='int32').isnull().sum(axis=1).plot(kind='hist')

# %% [markdown]
# # Distribution of our Target variable

# %%
# check if the target variable is imbalanced
print "number of clients that took  offer on product: %s" % (100*data['SS'].sum()/float(data.shape[0]))
# Out:
# number of clients that took  offer on product: 19.842142857142857

# %%
data['SS'].hist()

# %%
_ = data.hist(figsize=(25, 12.5))

# %%
data.groupby('SS').hist(figsize=(25, 12.5))
# Out:
# SS
# 0    [[AxesSubplot(0.125,0.758226;0.158163x0.121774...
# 1    [[AxesSubplot(0.125,0.758226;0.158163x0.121774...
# dtype: object
